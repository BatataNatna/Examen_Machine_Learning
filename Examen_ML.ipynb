# %% [markdown]
# # Khedoudja Rym MERAD
#
# Examen de ML
#
# IA M2 Data Science E-Learning

# %% [markdown]
# ## Exercice de cours
#
#
# **Question1:**
# - L'apprentissage supervisé est le type de ML qui permet de donner des resultats attendus comme le KNN nous savons de quelle forme sera le résultat et quelle chemin l'IA a pris pour l'atteindre car nous pouvons changer les hyperparamètres et l'adapter à nos besoins.
# Ne peut être appliqué que lorsque qu'on a des données structurées en classes commes des classes de type chien/chat.
#
#
# - L'aprentissage non suprvisé est le type de ML qui ne nous donne pas la main pour choisir le chemin que l'IA doit prendre afin d'arriver au résultat comme le PCA que nous ne pouvons pas adapter à l'aide d'hyperparamètres.
# Il permet de connaitre la structure des données.
#
# - La fonction de cout permet de savoir combien de données d'entrainement optimale il faut pour éviter les cas d'over/underfitting
#
# - Les hyperparamètres sont les paramètres à rentrer dans un modèle d'IA pour permettre de changer la liberté du résultat, pour les modèles de type  sarima par exemple elles nous permettent de changer la fenetre de saisonalité et inci induire le résultat vers des solutions adaptées à nos besoins
#
# - La matrice de confusion est un critère de réussite qu'on utilise afin de vérifier les performances des IA en montrant par exemple les données bien prédites et correctes, les données mal prédites mais compté comme correctes, les données mal prédites et comptées comme fausses et les données bien prédites comptées comme fausses
#
#
#
#
# **Question 2 :** Le clustering est un type de résultat attendu pour certains type de ML comme PCA et qui consiste à regrouper les individus, des mots ou données similaires ensemble sur une carte comme PCA.
# La classification quant à elle permet de se baser sur des classes définies afin de donner la classe d'une donnée en entrée comme dire si une photo apartient à un chien ou un chat

# %% [markdown]
# ## Exercice 2

# %% [markdown]
# ### Import des bibliothèques

# %%
#traitement des données 
import numpy as np 
import pandas as pd

#Tracer les graphes
import seaborn as sns
import matplotlib.pyplot as plt

#standardisation et normalisation
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Import des bases

# %%
train = pd.read_table("synth_test.txt")
train.head()
# Out:
#    y        x1        x2
# 0  2  0.548377  1.221345
# 1  2 -0.516182  1.562396
# 2  2 -0.928778  0.921072
# 3  2  0.070004  0.619767
# 4  2  0.267028  1.109441

# %%
test = pd.read_table("synth_test.txt")
test.head()
# Out:
#    y        x1        x2
# 0  2  0.548377  1.221345
# 1  2 -0.516182  1.562396
# 2  2 -0.928778  0.921072
# 3  2  0.070004  0.619767
# 4  2  0.267028  1.109441

# %% [markdown]
# ### Descrire les données

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   y       200 non-null    int64
#  1   x1      200 non-null    float64
#  2   x2      200 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 4.8 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   y       200 non-null    int64
#  1   x1      200 non-null    float64
#  2   x2      200 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 4.8 KB

# %%
train.describe()
# Out:
#                 y          x1          x2
# count  200.000000  200.000000  200.000000
# mean     1.690000   -0.308822    1.322626
# std      0.463654    0.692767    0.745400
# min      1.000000   -2.461341   -0.289020
# 25%      1.000000   -0.654509    0.836470
# 50%      2.000000   -0.201318    1.198818
# 75%      2.000000    0.123631    1.704828
# max      2.000000    1.133675    3.873351

# %%
test.describe()
# Out:
#                 y          x1          x2
# count  200.000000  200.000000  200.000000
# mean     1.690000   -0.308822    1.322626
# std      0.463654    0.692767    0.745400
# min      1.000000   -2.461341   -0.289020
# 25%      1.000000   -0.654509    0.836470
# 50%      2.000000   -0.201318    1.198818
# 75%      2.000000    0.123631    1.704828
# max      2.000000    1.133675    3.873351

# %%
train.isna().sum()
# Out:
# y     0
# x1    0
# x2    0
# dtype: int64

# %%
test.isna().sum()
# Out:
# y     0
# x1    0
# x2    0
# dtype: int64

# %%
y = train["y"]
x = train.drop('y', axis=1)
plt.scatter(x.iloc[:, 0], x.iloc[:, 1], c=y, alpha=0.8, cmap='viridis')
plt.grid()

# %%
train.corr()
# Out:
#            y        x1        x2
# y   1.000000  0.639929 -0.709085
# x1  0.639929  1.000000 -0.287910
# x2 -0.709085 -0.287910  1.000000

# %%
# Standardiser les données de train
scaler = StandardScaler()
data_std_train = scaler.fit_transform(train)
data_train = pd.DataFrame(data_std_train, columns=train.columns)
print(data_train)


# Normalisation des données de train
scaler = MinMaxScaler()
df_normalized_train = scaler.fit_transform(data_train)
data= pd.DataFrame(df_normalized_train, columns=data_train.columns)
print(data_train)


# Standardiser les données de test
scaler = StandardScaler()
data_std_test= scaler.fit_transform(test)
data_test = pd.DataFrame(data_std_test, columns=test.columns)
print(data_test)


# Normalisation des données de test
scaler = MinMaxScaler()
df_normalized_test= scaler.fit_transform(data)
data_test= pd.DataFrame(df_normalized_test, columns=data.columns)
print(data_test)
# Out:
#             y        x1        x2
# 0    0.670280  1.240462 -0.136215
# 1    0.670280 -0.300073  0.322474
# 2    0.670280 -0.897144 -0.540060
# 3    0.670280  0.548203 -0.945294
# 4    0.670280  0.833319 -0.286718
# ..        ...       ...       ...
# 195  0.670280  0.636270 -1.148219
# 196  0.670280 -0.392716 -0.507149
# 197  0.670280 -0.097185 -0.644104
# 198  0.670280  1.710411 -0.157819
# 199 -1.491914 -1.230837  0.569173
#
# [200 rows x 3 columns]
#             y        x1        x2
# 0    0.670280  1.240462 -0.136215
# 1    0.670280 -0.300073  0.322474
# 2    0.670280 -0.897144 -0.540060
# 3    0.670280  0.548203 -0.945294
# 4    0.670280  0.833319 -0.286718
# ..        ...       ...       ...
# 195  0.670280  0.636270 -1.148219
# 196  0.670280 -0.392716 -0.507149
# 197  0.670280 -0.097185 -0.644104
# 198  0.670280  1.710411 -0.157819
# 199 -1.491914 -1.230837  0.569173
#
# [200 rows x 3 columns]
#             y        x1        x2
# 0    0.670280  1.240462 -0.136215
# ...

# %% [markdown]
# ### Préparation du modèle

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=30)

# %%
y_train = data_train['y']
x_train = data_train.drop(columns='y')
model.fit(x,y)
model.score(x,y)
# Out:
# 0.95

# %%
def prediction(model,x1,x2):
    x = np.array([x1,x2]).reshape(1,2)
    print(model.predict(x))

    # tester avec un point
prediction(model,3,-2)
# Out:
# [2]
# c:\Users\rymkm\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
y_test = data_test['y']
x_test = data_test.drop(columns='y')

for i in range(101):
    x1 = x_test[i:i+1]['x1']
    x2 =  x_test[i:i+1]['x2']
    prediction(model,x1,x2)
# Out:
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# [2]
# c:\Users\rymkm\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\rymkm\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\rymkm\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\rymkm\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\rymkm\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
# ...
